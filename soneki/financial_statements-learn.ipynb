# %% [markdown]
# ## 連結損益計算書(単位百万円)

# %%
import numpy as np
import pandas as pd

pd.read_csv('data/sharp.csv', index_col='事項' )
# Out:
#              前連結会計年度(自 平成26年4月1日 至 平成27年3月31日)  \
# 事項
# 売上高                                  2,786,256
# 売上原価                                 2,397,749
# 売上総利益                                  388,507
# 販売費及びー般管理費                             436,572
# 営業損失                                   △48,065
# 営業外収益                                   22,181
# 営業外費用                                   70,642
# 経常損失                                   △96,526
# 特別利益                                    53,299
# 特別損失                                   145,607
# 税金等調整前当期純損失                           △188,834
# 法人税、住民税及び事業税                            27,179
# 法人税等調整額                                  4,234
# 法人税等合計                                  31,413
# 当期純損失                                 △220,247
#
#              当連結会計年度(自平成27年3月31日 至平成28年3月31日)
# 事項
# 売上高                                 2,461,589
# 売上原価                                2,228,277
# 売上総利益                                 233,312
# ...

# %% [markdown]
# Observation
# - Low value compared to other electronics companies
